# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
data1= ['a','b','c','d','e']
print(data1)
print(type(data1))

sr1 = pd.Series(data1)
print(sr1)
print(type(sr1))
# Out:
# ['a', 'b', 'c', 'd', 'e']
# <class 'list'>
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
#시리즈 객체의 원소를 추출할 때는 loc 인덱서를 사용!
sr1.loc[1:3]
# Out:
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
data2 = (1, 2, 3.14, 100, -10)
sr2 = pd.Series(data2)
sr2
# Out:
# 0      1.00
# 1      2.00
# 2      3.14
# 3    100.00
# 4    -10.00
# dtype: float64

# %%
dict_data = {'c0':sr1, 'c1':sr2}
df1 = pd.DataFrame(dict_data)
df1
# Out:
#   c0      c1
# 0  a    1.00
# 1  b    2.00
# 2  c    3.14
# 3  d  100.00
# 4  e  -10.00

# %%
df1.columns
# Out:
# Index(['c0', 'c1'], dtype='object')

# %%
df1.columns = ['string','number']
df1
# Out:
#   string  number
# 0      a    1.00
# 1      b    2.00
# 2      c    3.14
# 3      d  100.00
# 4      e  -10.00

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df1.index = ['r0','r1','r2','r3','r4']
df1
# Out:
#    string  number
# r0      a    1.00
# r1      b    2.00
# r2      c    3.14
# r3      d  100.00
# r4      e  -10.00

# %%
df1.loc['r2','number']
# Out:
# 3.14

# %%
df1.loc['r2':'r3','string':'number']
# Out:
#    string  number
# r2      c    3.14
# r3      d  100.00
